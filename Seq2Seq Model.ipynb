# %%
# https://github.com/bentrevett/pytorch-seq2seq/blob/master/1%20-%20Sequence%20to%20Sequence%20Learning%20with%20Neural%20Networks.ipynb
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import TranslationDataset, Multi30k
from torchtext.data import Field, BucketIterator, ReversibleField
from nltk.translate.bleu_score import sentence_bleu
import spacy

import random
import math
import os

# %%
SEED = 1

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
spacy_de = spacy.load('de')
spacy_en = spacy.load('en')

# %%
def tokenize_de(text):
    """
    Tokenizes German text from a string into a list of strings (tokens) and reverses it
    """
    return [tok.text for tok in spacy_de.tokenizer(text)][::-1]

def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings (tokens)
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
SRC = Field(tokenize=tokenize_de, init_token='<sos>', eos_token='<eos>', lower=True)
TRG = Field(tokenize=tokenize_en, init_token='<sos>', eos_token='<eos>', lower=True)
# TEXT = ReversibleField(sequential=True, lower=True, include_lengths=True)

train_data, valid_data, test_data = Multi30k.splits(exts=('.de', '.en'), fields=(SRC, TRG))

print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 29000
# Number of validation examples: 1014
# Number of testing examples: 1000

# %%
print(vars(train_data.examples[0]))
# Out:
# {'src': ['.', 'büsche', 'vieler', 'nähe', 'der', 'in', 'freien', 'im', 'sind', 'männer', 'weiße', 'junge', 'zwei'], 'trg': ['two', 'young', ',', 'white', 'males', 'are', 'outside', 'near', 'many', 'bushes', '.']}

# %%
SRC.build_vocab(train_data, min_freq=2)
TRG.build_vocab(train_data, min_freq=2)

print(f"Unique tokens in source (de) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (en) vocabulary: {len(TRG.vocab)}")
print(TRG.vocab.stoi["two"])
print(TRG.vocab.stoi["young"])
trg_arr = [   4,   14,    6,    4,  314,  109,   10,   32,   11, 2763,   20,    4,  94,   15,   13,    4,  531,   12,  121,   18,  413,  344,   44,    5,3]
for elem in trg_arr:
    print(TRG.vocab.itos[elem])
# print(TEXT.reverse(torch.tensor(trg_arr)))
# Out:
# Unique tokens in source (de) vocabulary: 7853
# Unique tokens in target (en) vocabulary: 5893
# 16
# 24
# a
# woman
# in
# a
# tank
# top
# is
# sitting
# and
# knitting
# at
# a
# table
# ,
# with
# a
# bottle
# of
# something
# to
# drink
# beside
# her
# .
# <eos>

# %%
BATCH_SIZE = 128

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), batch_size=BATCH_SIZE, device=device)
# Out:
# cpu

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout=dropout)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [sent len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [sent len, batch size, emb dim]
        
        outputs, (hidden, cell) = self.rnn(embedded)
        
        #outputs = [sent len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #outputs are always from the top hidden layer
        
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()

        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.output_dim = output_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout=dropout)
        
        self.out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell):
        
        #input = [batch size]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #n directions in the decoder will both always be 1, therefore:
        #hidden = [n layers, batch size, hid dim]
        #context = [n layers, batch size, hid dim]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
                
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        
        #output = [sent len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #sent len and n directions will always be 1 in the decoder, therefore:
        #output = [1, batch size, hid dim]
        #hidden = [n layers, batch size, hid dim]
        #cell = [n layers, batch size, hid dim]
        
        prediction = self.out(output.squeeze(0))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
        assert encoder.hid_dim == decoder.hid_dim, "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, "Encoder and decoder must have equal number of layers!"
        
    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        
        #src = [sent len, batch size]
        #trg = [sent len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        
        batch_size = trg.shape[1]
        max_len = trg.shape[0]
#         print("trg shape", trg.shape)
        trg_vocab_size = self.decoder.output_dim
#         print("batch size ", batch_size)
#         print("max len ", max_len)
#         print("trg vocab size ", trg_vocab_size)
        
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
#         print("shape of outputs")
#         print(outputs.shape)
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
#         print("first input")
#         print(input)
        for t in range(1, max_len):
#             print("in LOOP")
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
#             print("output in loop")
#             print(output)
#             print(output.max(1))
            top1 = output.max(1)[1] # index of the max value
            input = (trg[t] if teacher_force else top1)
        
        return outputs

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, device).to(device)

optimizer = optim.Adam(model.parameters())

pad_idx = TRG.vocab.stoi['<pad>']

criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        print("train iterator ", i)
        src = batch.src
        trg = batch.trg
        optimizer.zero_grad()
        
        output = model(src, trg)
        #trg = [sent len, batch size]
        #output = [sent len, batch size, output dim]
        
        #trg_a = [sent len, batch size]
        #output_b = [sent len, batch size, output dim]
        
        #reshape to:
        #trg = [(sent len - 1) * batch size]
        #output = [(sent len - 1) * batch size, output dim]


#         x = output[1:].view(-1, output.shape[2])
#         y = trg[1:].view(-1)
        

        loss = criterion(output[1:].view(-1, output.shape[2]), trg[1:].view(-1))
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
        
    return epoch_loss / len(iterator)

# %%
import torch
def process_final(t):
    sentences = []
    for i in range(len(t[0])):
        tensor_out = t[:, i]
        tensor_out = list(tensor_out.numpy())
        sentence = []
        for j in tensor_out:
            if TRG.vocab.itos[j] == '<pad>':
                break
            if TRG.vocab.itos[j] == '<eos>':
                sentence.append(TRG.vocab.itos[j])
                break
            sentence.append(TRG.vocab.itos[j])
        sentences.append(sentence)
    return sentences


def process_output(output):
    y = []
    for elem in output:
        x = []
        z = []
        for arr in elem:
            values, indices = arr.max(0)
            x.append(indices.item())
            z.append(values.item())
#         print("printing x")
#         print(x)
#         print("printing z")
#         print(z)


        y.append(x)
    final_tensor = torch.tensor(y)
    print("final tensor ")
    print(final_tensor)
    return process_final(final_tensor)

# %%
def evaluate(model, iterator, criterion, testing):
    
    model.eval()
    
    epoch_loss = 0
    bleu_score = 0
    count_pair = 0
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg
            
            output = model(src, trg, 0) #turn off teacher forcing
            if testing:
                output_a = output[1:]
                trg_a = trg[1:]

                sent_out = process_output(output_a)
                sent_trg = process_final(trg_a)
                for o, t in zip(sent_out, sent_trg):
                    reference = [t]
                    candidate = o
                    print("reference ")
                    print(reference)
                    print("candidate ")
                    print(candidate)
                    bleu_score += sentence_bleu(reference, candidate)
                    count_pair += 1




#             print("output sentences ")
#             print(output_a)
#             print("after processing")
#             print(sent_out)
#             print("target sentences")
#             print(trg_a)
#             print("after processing")
#             print(sent_trg)
            
            
            
            
            x = output[1:].view(-1, output.shape[2])
            y = trg[1:].view(-1)
            
            
        
            

            loss = criterion(output[1:].view(-1, output.shape[2]), trg[1:].view(-1))

            epoch_loss += loss.item()
        if testing:
            print("count pair ", count_pair)
            print("bleu score ")


            print(bleu_score / count_pair)
    return epoch_loss / len(iterator)

# %%
N_EPOCHS = 10
CLIP = 1
SAVE_DIR = 'models'
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'seq_2_seq.pt')

best_valid_loss = float('inf')

if not os.path.isdir(f'{SAVE_DIR}'):
    os.makedirs(f'{SAVE_DIR}')

for epoch in range(N_EPOCHS):
    print("epoch ", epoch)
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion, False)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), MODEL_SAVE_PATH)
    
    print(f'| Epoch: {epoch+1:03} | Train Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f} | Val. Loss: {valid_loss:.3f} | Val. PPL: {math.exp(valid_loss):7.3f} |')
    print(f'| Epoch: {epoch+1:03} | Train Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}  |')
# Out:
# epoch  0
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 001 | Train Loss: 5.006 | Train PPL: 149.340 | Val. Loss: 4.836 | Val. PPL: 125.981 |
# | Epoch: 001 | Train Loss: 5.006 | Train PPL: 149.340  |
# epoch  1
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 002 | Train Loss: 4.463 | Train PPL:  86.735 | Val. Loss: 4.692 | Val. PPL: 109.118 |
# | Epoch: 002 | Train Loss: 4.463 | Train PPL:  86.735  |
# epoch  2
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 003 | Train Loss: 4.219 | Train PPL:  67.985 | Val. Loss: 4.503 | Val. PPL:  90.263 |
# | Epoch: 003 | Train Loss: 4.219 | Train PPL:  67.985  |
# epoch  3
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 004 | Train Loss: 4.030 | Train PPL:  56.260 | Val. Loss: 4.348 | Val. PPL:  77.359 |
# | Epoch: 004 | Train Loss: 4.030 | Train PPL:  56.260  |
# epoch  4
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 005 | Train Loss: 3.860 | Train PPL:  47.458 | Val. Loss: 4.288 | Val. PPL:  72.821 |
# | Epoch: 005 | Train Loss: 3.860 | Train PPL:  47.458  |
# epoch  5
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 006 | Train Loss: 3.703 | Train PPL:  40.558 | Val. Loss: 4.180 | Val. PPL:  65.368 |
# | Epoch: 006 | Train Loss: 3.703 | Train PPL:  40.558  |
# epoch  6
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 007 | Train Loss: 3.590 | Train PPL:  36.238 | Val. Loss: 4.031 | Val. PPL:  56.295 |
# | Epoch: 007 | Train Loss: 3.590 | Train PPL:  36.238  |
# epoch  7
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 008 | Train Loss: 3.467 | Train PPL:  32.043 | Val. Loss: 4.005 | Val. PPL:  54.848 |
# | Epoch: 008 | Train Loss: 3.467 | Train PPL:  32.043  |
# epoch  8
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 009 | Train Loss: 3.366 | Train PPL:  28.965 | Val. Loss: 3.969 | Val. PPL:  52.937 |
# | Epoch: 009 | Train Loss: 3.366 | Train PPL:  28.965  |
# epoch  9
# train iterator  0
# train iterator  1
# train iterator  2
# train iterator  3
# train iterator  4
# train iterator  5
# train iterator  6
# train iterator  7
# train iterator  8
# train iterator  9
# train iterator  10
# train iterator  11
# train iterator  12
# train iterator  13
# train iterator  14
# train iterator  15
# train iterator  16
# train iterator  17
# train iterator  18
# train iterator  19
# train iterator  20
# train iterator  21
# train iterator  22
# train iterator  23
# train iterator  24
# train iterator  25
# train iterator  26
# train iterator  27
# train iterator  28
# train iterator  29
# train iterator  30
# train iterator  31
# train iterator  32
# train iterator  33
# train iterator  34
# train iterator  35
# train iterator  36
# train iterator  37
# train iterator  38
# train iterator  39
# train iterator  40
# train iterator  41
# train iterator  42
# train iterator  43
# train iterator  44
# train iterator  45
# train iterator  46
# train iterator  47
# train iterator  48
# train iterator  49
# train iterator  50
# train iterator  51
# train iterator  52
# train iterator  53
# train iterator  54
# train iterator  55
# train iterator  56
# train iterator  57
# train iterator  58
# train iterator  59
# train iterator  60
# train iterator  61
# train iterator  62
# train iterator  63
# train iterator  64
# train iterator  65
# train iterator  66
# train iterator  67
# train iterator  68
# train iterator  69
# train iterator  70
# train iterator  71
# train iterator  72
# train iterator  73
# train iterator  74
# train iterator  75
# train iterator  76
# train iterator  77
# train iterator  78
# train iterator  79
# train iterator  80
# train iterator  81
# train iterator  82
# train iterator  83
# train iterator  84
# train iterator  85
# train iterator  86
# train iterator  87
# train iterator  88
# train iterator  89
# train iterator  90
# train iterator  91
# train iterator  92
# train iterator  93
# train iterator  94
# train iterator  95
# train iterator  96
# train iterator  97
# train iterator  98
# train iterator  99
# train iterator  100
# train iterator  101
# train iterator  102
# train iterator  103
# train iterator  104
# train iterator  105
# train iterator  106
# train iterator  107
# train iterator  108
# train iterator  109
# train iterator  110
# train iterator  111
# train iterator  112
# train iterator  113
# train iterator  114
# train iterator  115
# train iterator  116
# train iterator  117
# train iterator  118
# train iterator  119
# train iterator  120
# train iterator  121
# train iterator  122
# train iterator  123
# train iterator  124
# train iterator  125
# train iterator  126
# train iterator  127
# train iterator  128
# train iterator  129
# train iterator  130
# train iterator  131
# train iterator  132
# train iterator  133
# train iterator  134
# train iterator  135
# train iterator  136
# train iterator  137
# train iterator  138
# train iterator  139
# train iterator  140
# train iterator  141
# train iterator  142
# train iterator  143
# train iterator  144
# train iterator  145
# train iterator  146
# train iterator  147
# train iterator  148
# train iterator  149
# train iterator  150
# train iterator  151
# train iterator  152
# train iterator  153
# train iterator  154
# train iterator  155
# train iterator  156
# train iterator  157
# train iterator  158
# train iterator  159
# train iterator  160
# train iterator  161
# train iterator  162
# train iterator  163
# train iterator  164
# train iterator  165
# train iterator  166
# train iterator  167
# train iterator  168
# train iterator  169
# train iterator  170
# train iterator  171
# train iterator  172
# train iterator  173
# train iterator  174
# train iterator  175
# train iterator  176
# train iterator  177
# train iterator  178
# train iterator  179
# train iterator  180
# train iterator  181
# train iterator  182
# train iterator  183
# train iterator  184
# train iterator  185
# train iterator  186
# train iterator  187
# train iterator  188
# train iterator  189
# train iterator  190
# train iterator  191
# train iterator  192
# train iterator  193
# train iterator  194
# train iterator  195
# train iterator  196
# train iterator  197
# train iterator  198
# train iterator  199
# train iterator  200
# train iterator  201
# train iterator  202
# train iterator  203
# train iterator  204
# train iterator  205
# train iterator  206
# train iterator  207
# train iterator  208
# train iterator  209
# train iterator  210
# train iterator  211
# train iterator  212
# train iterator  213
# train iterator  214
# train iterator  215
# train iterator  216
# train iterator  217
# train iterator  218
# train iterator  219
# train iterator  220
# train iterator  221
# train iterator  222
# train iterator  223
# train iterator  224
# train iterator  225
# train iterator  226
# | Epoch: 010 | Train Loss: 3.273 | Train PPL:  26.395 | Val. Loss: 3.879 | Val. PPL:  48.367 |
# | Epoch: 010 | Train Loss: 3.273 | Train PPL:  26.395  |

# %%
model.load_state_dict(torch.load(MODEL_SAVE_PATH))

test_loss = evaluate(model, test_iterator, criterion, True)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# final tensor
# tensor([[ 16, 110,   4,  ...,   4,  24,  16],
#         [112,  19,  34,  ...,  14,  14,  30],
#         [112,  17,  10,  ...,  10,  10,  22],
#         ...,
#         [  5,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])
# reference
# [['two', 'medium', 'sized', 'dogs', 'run', 'across', 'the', 'snow', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'dogs', 'running', 'through', 'the', 'snow', '.', '<eos>']
# reference
# [['four', 'people', 'are', 'playing', 'soccer', 'on', 'a', 'beach', '.', '<eos>']]
# candidate
# ['four', 'people', 'are', 'playing', 'on', 'the', 'beach', '.', '<eos>']
# reference
# [['a', 'boy', 'riding', 'a', 'skateboard', 'on', 'a', 'skateboarding', 'ramp', '<eos>']]
# candidate
# ['a', 'boy', 'is', 'riding', 'a', 'a', 'on', 'a', '.', '.', '<eos>']
# reference
# [['a', 'dog', 'is', 'jumping', 'through', 'a', '<unk>', 'obstacle', '.', '<eos>']]
# candidate
# ['a', 'dog', 'jumps', 'through', 'a', 'air', '.', '<eos>']
# reference
# [['the', 'two', 'kids', 'are', 'playing', 'at', 'the', 'playground', '.', '<eos>']]
# candidate
# ['two', 'children', 'playing', 'playing', 'on', 'on', 'the', '.', '<eos>']
# reference
# [['girl', 'wearing', 'radio', 't', '-', 'shirt', 'has', 'open', 'mouth', '<eos>']]
# candidate
# ['a', 'girl', 'in', 'a', 'pink', 'dress', 'is', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'brown', 'dog', 'runs', 'down', 'the', 'sandy', 'beach', '.', '<eos>']]
# candidate
# ['a', 'black', 'dog', 'is', 'running', 'through', 'the', 'water', '.', '<eos>']
# reference
# [['an', 'asian', 'factory', 'worker', 'posing', 'for', 'the', 'camera', '.', '<eos>']]
# candidate
# ['a', 'smiling', 'couple', 'is', 'her', 'her', 'camera', '.', '<eos>']
# reference
# [['a', 'boy', 'in', 'shorts', 'doing', 'a', 'skateboard', 'trick', '.', '<eos>']]
# candidate
# ['a', 'boy', 'in', 'a', 'blue', 'is', 'is', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'chinese', 'man', 'sitting', 'down', 'waiting', 'for', 'customers', '.', '<eos>']]
# candidate
# ['a', 'man', 'sitting', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['two', 'workers', 'spread', 'cement', 'onto', 'a', 'brick', 'building', '.', '<eos>']]
# candidate
# ['two', 'women', 'are', 'on', 'a', 'a', 'on', 'a', '.', '.', '<eos>']
# reference
# [['people', '<unk>', 'in', 'at', 'forest', 'next', 'to', 'canoes', '.', '<eos>']]
# candidate
# ['people', 'are', 'in', 'a', 'city', 'city', '.', '<eos>']
# reference
# [['a', 'black', 'dog', '<unk>', 'up', 'into', 'a', 'pool', '.', '<eos>']]
# candidate
# ['a', 'black', 'dog', 'is', 'in', 'a', 'pool', '.', '<eos>']
# reference
# [['a', 'man', 'using', 'a', 'chainsaw', 'to', 'cut', '<unk>', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'woman', 'is', 'holding', 'a', 'small', 'white', 'statue', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'a', 'little', 'girl', '.', '<eos>']
# reference
# [['two', 'brown', 'dogs', 'are', 'running', 'through', 'the', 'snow', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'dogs', 'running', 'through', 'the', 'snow', '.', '<eos>']
# reference
# [['two', 'young', 'boys', 'putting', 'fruit', 'on', 'the', 'bike', '.', '<eos>']]
# candidate
# ['two', 'young', 'boys', 'are', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'cheerleading', 'team', 'doing', 'a', 'routine', 'on', 'chairs', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'is', 'a', 'a', 'on', 'a', '.', '.', '<eos>']
# reference
# [['the', 'young', 'lady', 'is', 'looking', 'at', 'the', 'pizza', '.', '<eos>']]
# candidate
# ['young', 'young', 'man', 'is', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['men', 'play', 'soccer', 'on', 'a', 'muddy', 'field', '.', '<eos>']]
# candidate
# ['men', 'playing', 'on', 'a', 'field', 'with', 'a', '.', '<eos>']
# reference
# [['a', 'girl', 'plays', 'in', 'a', 'small', 'pool', '.', '<eos>']]
# candidate
# ['a', 'girl', 'playing', 'in', 'a', 'pool', 'pool', '.', '<eos>']
# reference
# [['the', '<unk>', '<unk>', 'water', 'during', 'his', '<unk>', '.', '<eos>']]
# candidate
# ['the', '<unk>', 'is', 'the', 'the', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['3', 'men', 'cooking', 'in', 'a', 'small', 'kitchen', '.', '<eos>']]
# candidate
# ['three', 'men', 'are', 'in', 'a', 'a', 'in', '.', '<eos>']
# reference
# [['two', 'individual', 'climbing', 'up', 'a', 'steep', 'mountain', '.', '<eos>']]
# candidate
# ['two', 'people', 'are', 'through', 'a', 'boat', '.', '<eos>']
# reference
# [['man', 'carrying', 'a', 'few', '<unk>', 'of', 'beer', '.', '<eos>']]
# candidate
# ['a', 'man', 'with', 'a', '<unk>', 'of', 'food', '.', '<eos>']
# reference
# [['a', 'child', 'is', 'on', 'a', 'motorcycle', 'smiling', '.', '<eos>']]
# candidate
# ['a', 'child', 'is', 'on', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['a', 'crane', 'operates', 'amidst', 'piles', 'of', 'rubble', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'is', 'in', 'a', 'a', 'in', 'a', '.', '.', '<eos>']
# reference
# [['man', 'in', 'shorts', 'standing', 'by', 'the', 'water', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'is', 'is', 'walking', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'brown', 'dog', 'jumping', 'over', 'a', 'hurdle', '.', '<eos>']]
# candidate
# ['a', 'brown', 'dog', 'is', 'running', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'person', 'is', 'playing', 'an', 'unique', 'instrument', '.', '<eos>']]
# candidate
# ['a', 'person', 'playing', 'on', 'a', 'stage', '.', '<eos>']
# reference
# [['<unk>', '<unk>', 'are', 'marching', 'with', 'the', 'band', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['three', 'people', 'smiling', 'and', 'holding', 'political', 'signs', '.', '<eos>']]
# candidate
# ['three', 'people', 'and', 'two', 'people', 'are', '.', '<eos>']
# reference
# [['an', 'asian', 'man', 'is', 'cooking', 'food', 'outdoors', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'food', 'food', '.', '<eos>']
# reference
# [['a', 'blond', 'child', 'swinging', 'on', 'a', 'swing', '.', '<eos>']]
# candidate
# ['a', 'young', 'child', 'is', 'on', 'a', 'swing', '.', '<eos>']
# reference
# [['the', 'boy', 'is', 'wakeboarding', 'on', 'the', 'lake', '.', '<eos>']]
# candidate
# ['a', 'young', 'boy', 'is', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['three', 'teenagers', 'in', 'a', 'subway', 'playing', 'around', '.', '<eos>']]
# candidate
# ['three', 'guys', 'in', 'a', 'a', 'in', '.', '<eos>']
# reference
# [['a', 'man', 'cooking', 'food', 'on', 'the', 'stove', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'at', 'the', 'window', 'of', 'a', '.', '.', '<eos>']
# reference
# [['two', 'groups', 'of', 'swimmers', 'wade', 'out', '.', '<eos>']]
# candidate
# ['two', 'men', 'are', 'in', 'the', 'air', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['two', 'bald', 'drag', '<unk>', 'in', 'red', 'dresses', '<eos>']]
# candidate
# ['two', '<unk>', 'in', 'white', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['hockey', 'player', 'in', 'white', 'uniform', 'with', 'stick', '<eos>']]
# candidate
# ['a', 'in', 'in', 'a', 'white', 'jersey', '.', '<eos>']
# reference
# [['a', 'man', 'doing', 'a', 'trick', 'on', 'skateboard', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['three', 'construction', 'workers', 'are', '<unk>', 'pavement', '.', '<eos>']]
# candidate
# ['three', '<unk>', 'on', 'the', 'on', 'the', '.', '.', '<eos>']
# reference
# [['man', 'scaling', 'wall', 'with', 'fire', 'in', 'hand', '<eos>']]
# candidate
# ['man', 'is', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'pretty', 'woman', 'plays', 'a', '<unk>', '.', '<eos>']]
# candidate
# ['a', 'woman', 'woman', 'playing', 'on', 'a', 'stage', '.', '<eos>']
# reference
# [['people', 'standing', 'outside', 'of', 'a', 'building', '.', '<eos>']]
# candidate
# ['people', 'are', 'in', 'front', 'of', 'a', 'building', '.', '<eos>']
# reference
# [['two', 'construction', 'workers', 'have', 'a', 'discussion', 'while', 'on', 'the', 'work', 'site', '.', '<eos>']]
# candidate
# ['two', 'construction', 'workers', 'are', 'on', 'a', 'a', '.', '.', '<eos>']
# reference
# [['the', 'girl', 'is', 'taking', 'a', 'drink', 'from', 'a', 'water', 'fountain', '.', '<eos>']]
# candidate
# ['girl', 'in', 'the', 'air', 'at', 'a', 'pool', '.', '<eos>']
# reference
# [['people', 'are', 'looking', 'at', 'children', "'s", 'toys', 'in', 'a', 'store', '.', '<eos>']]
# candidate
# ['people', 'are', 'in', 'a', 'a', 'in', 'a', '.', '.', '<eos>']
# reference
# [['people', 'look', 'on', 'as', 'participants', 'in', 'a', 'marathon', 'pass', 'by', '.', '<eos>']]
# candidate
# ['people', 'are', 'watching', 'the', 'people', '.', '<eos>']
# reference
# [['a', 'window', 'with', 'some', 'type', 'of', 'design', 'painted', 'on', 'it', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'with', 'a', '<unk>', '.', '<eos>']
# reference
# [['two', 'people', 'standing', 'next', 'to', 'a', 'tree', 'on', 'the', 'ground', '.', '<eos>']]
# candidate
# ['two', 'people', 'standing', 'on', 'a', 'sunny', 'day', '.', '<eos>']
# reference
# [['three', 'dogs', 'play', 'with', 'each', 'other', 'out', 'in', 'the', 'field', '.', '<eos>']]
# candidate
# ['three', 'dogs', 'are', 'playing', 'in', 'the', 'field', '.', '<eos>']
# reference
# [['a', 'man', 'talks', 'on', 'the', 'phone', 'with', 'his', 'feet', 'up', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'with', 'his', 'hands', '.', '<eos>']
# reference
# [['an', 'older', 'man', 'is', 'playing', 'a', 'video', 'arcade', 'game', '.', '<eos>']]
# candidate
# ['a', 'man', 'man', 'playing', 'guitar', '.', '<eos>']
# reference
# [['two', 'teams', 'of', 'boys', 'playing', 'football', 'in', 'the', 'sand', '.', '<eos>']]
# candidate
# ['two', 'teams', 'dogs', 'are', 'playing', 'in', 'the', 'water', '.', '<eos>']
# reference
# [['two', 'construction', 'workers', 'are', 'laying', 'sheet', 'metal', 'across', 'beams', '.', '<eos>']]
# candidate
# ['two', '<unk>', 'players', 'are', '<unk>', 'to', 'the', '.', '<eos>']
# reference
# [['a', 'cat', 'sits', 'on', 'top', 'of', 'a', 'store', 'sign', '.', '<eos>']]
# candidate
# ['a', 'sitting', 'on', 'a', 'bench', '.', '<eos>']
# reference
# [['a', 'woman', 'is', '<unk>', 'plant', 'fluid', 'in', 'a', 'tribal', 'village', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'a', 'a', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'are', 'playing', 'on', 'an', 'object', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'children', 'playing', 'on', 'a', 'stage', '.', '<eos>']
# reference
# [['two', 'people', 'stand', 'at', 'the', 'peak', 'of', 'a', 'mountain', '.', '<eos>']]
# candidate
# ['two', 'men', 'are', 'on', 'a', 'sidewalk', '.', '<eos>']
# reference
# [['a', 'family', 'going', 'for', 'a', 'walk', 'in', 'a', 'park', '.', '<eos>']]
# candidate
# ['a', 'family', 'is', 'through', 'a', 'city', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'sitting', 'next', 'to', 'a', 'computer', 'monitor', '.', '<eos>']]
# candidate
# ['a', 'man', 'sitting', 'on', 'a', 'bench', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'are', 'climbing', 'in', 'cold', 'weather', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'are', 'in', 'the', '.', '.', '<eos>']
# reference
# [['kids', 'compete', 'to', '<unk>', 'possession', 'of', 'the', 'soccer', 'ball', '.', '<eos>']]
# candidate
# ['children', 'are', 'to', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'cowboy', 'wrapping', 'up', 'his', 'arm', 'with', 'a', 'bandage', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', 'his', 'his', 'hand', '.', '<eos>']
# reference
# [['the', 'african', 'american', 'man', '<unk>', 'against', '<unk>', '<unk>', '.', '<eos>']]
# candidate
# ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['an', 'african', 'american', 'man', 'walking', 'down', 'the', 'street', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'walking', 'down', 'the', 'street', '.', '<eos>']
# reference
# [['a', 'young', 'man', 'about', 'to', 'throw', 'a', 'football', '.', '<eos>']]
# candidate
# ['a', 'young', 'man', 'is', 'a', 'a', 'ball', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'do', 'tricks', 'on', 'motorbikes', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'are', 'on', 'on', 'the', 'sidewalk', '.', '<eos>']
# reference
# [['a', 'brown', 'dog', 'is', 'digging', 'in', 'the', 'dirt', '.', '<eos>']]
# candidate
# ['a', 'brown', 'dog', 'is', 'in', 'the', 'snow', '.', '<eos>']
# reference
# [['young', 'kids', 'are', 'on', 'a', 'small', 'train', 'ride', '.', '<eos>']]
# candidate
# ['young', 'children', 'are', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'black', 'boy', 'is', 'sitting', 'in', 'the', 'sand', '.', '<eos>']]
# candidate
# ['a', 'young', 'boy', 'is', 'playing', 'in', 'the', 'snow', '.', '<eos>']
# reference
# [['parked', 'cars', 'with', 'a', 'school', 'bus', 'behind', 'them', '.', '<eos>']]
# candidate
# ['<unk>', '<unk>', 'with', 'a', '<unk>', '.', '<eos>']
# reference
# [['two', 'brown', 'dogs', 'playing', 'in', 'a', 'rough', 'manner', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'playing', 'playing', 'with', 'each', 'other', '.', '<eos>']
# reference
# [['a', 'brown', 'and', 'white', 'dog', 'fetching', 'a', 'toy', '.', '<eos>']]
# candidate
# ['a', 'black', 'and', 'white', 'dog', 'is', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'large', 'group', 'of', 'people', 'fill', 'a', 'street', '.', '<eos>']]
# candidate
# ['a', 'large', 'crowd', 'of', 'people', 'walking', 'down', 'the', 'street', '.', '<eos>']
# reference
# [['people', 'are', 'fixing', 'the', 'roof', 'of', 'a', 'house', '.', '<eos>']]
# candidate
# ['people', 'are', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'cars', 'are', 'driving', 'on', 'a', 'racetrack', '.', '<eos>']]
# candidate
# ['two', 'people', 'are', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['people', 'playing', 'a', 'game', 'in', 'the', 'pool', '.', '<eos>']]
# candidate
# ['people', 'are', 'playing', 'in', 'a', 'park', '.', '<eos>']
# reference
# [['three', 'men', 'are', 'cooking', 'in', 'a', 'kitchen', '.', '<eos>']]
# candidate
# ['three', 'men', 'are', 'in', 'in', 'a', 'park', '.', '<eos>']
# reference
# [['two', 'children', 'are', 'playing', 'on', 'a', 'bicycle', '.', '<eos>']]
# candidate
# ['two', 'children', 'playing', 'on', 'a', 'field', '.', '<eos>']
# reference
# [['crowds', 'of', 'people', 'are', 'all', 'riding', 'bicycles', '.', '<eos>']]
# candidate
# ['<unk>', '<unk>', '<unk>', 'the', '.', '<eos>']
# reference
# [['two', 'boys', 'are', 'playing', 'on', 'the', 'sidewalk', '.', '<eos>']]
# candidate
# ['two', 'boys', 'playing', 'on', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['three', 'girls', 'are', 'smiling', 'for', 'a', 'picture', '.', '<eos>']]
# candidate
# ['three', 'girls', 'are', 'posing', 'for', 'a', 'picture', '.', '<eos>']
# reference
# [['two', '<unk>', 'are', 'posing', 'for', 'a', 'picture', '.', '<eos>']]
# candidate
# ['two', 'ladies', 'are', 'for', 'a', 'picture', '.', '<eos>']
# reference
# [['construction', 'workers', '<unk>', 'against', '<unk>', 'construction', 'services', '.', '<eos>']]
# candidate
# ['<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['some', 'plants', 'are', 'growing', 'near', 'the', 'window', '.', '<eos>']]
# candidate
# ['a', 'couple', 'of', 'people', 'are', 'their', 'hands', '.', '<eos>']
# reference
# [['two', 'guys', 'with', '<unk>', 'piercings', 'are', 'smiling', '.', '<eos>']]
# candidate
# ['two', 'men', 'with', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['a', 'crowd', 'is', 'present', 'at', 'a', 'bar', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'in', 'a', 'parade', '.', '<eos>']
# reference
# [['an', 'asian', 'woman', '<unk>', 'her', 'hair', 'back', '.', '<eos>']]
# candidate
# ['a', 'asian', 'lady', 'is', 'her', 'her', '.', '<eos>']
# reference
# [['two', 'german', '<unk>', 'snarling', 'at', 'each', 'other', '.', '<eos>']]
# candidate
# ['two', '<unk>', 'are', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['a', '<unk>', 'terrier', 'leaps', 'after', 'a', 'ball', '.', '<eos>']]
# candidate
# ['a', 'baseball', 'player', 'is', 'jumping', 'into', 'the', 'air', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'working', 'a', 'hotdog', 'stand', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'working', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'boys', 'in', 'front', 'of', 'a', 'soda', 'machine', '.', '<eos>']]
# candidate
# ['two', 'boys', 'are', 'in', 'front', 'of', 'a', 'large', 'building', '.', '<eos>']
# reference
# [['a', 'guy', 'give', 'a', 'kiss', 'to', 'a', 'guy', 'also', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'mural', 'on', 'the', 'side', 'of', 'a', 'building', '.', '<eos>']]
# candidate
# ['a', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['construction', 'workers', 'having', 'a', 'discussion', 'by', 'the', 'tracks', '.', '<eos>']]
# candidate
# ['workers', 'are', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['two', 'boys', 'play', 'soccer', 'against', 'each', 'other', '.', '<eos>']]
# candidate
# ['two', 'young', 'boys', 'playing', 'soccer', '.', '<eos>']
# reference
# [['two', 'soccer', 'teams', 'are', 'on', 'the', 'field', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'are', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'light', 'brown', 'dog', 'is', 'running', 'up', '.', '<eos>']]
# candidate
# ['a', 'black', 'dog', 'is', 'running', 'on', 'the', '.', '<eos>']
# reference
# [['people', 'are', 'admiring', 'a', 'work', 'of', 'art', '.', '<eos>']]
# candidate
# ['people', 'are', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'boy', 'stands', 'with', 'three', 'girls', '.', '<eos>']]
# candidate
# ['a', 'young', 'girl', 'is', 'standing', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['two', 'men', 'sitting', 'in', 'a', 'restaurant', '.', '<eos>']]
# candidate
# ['two', 'men', 'are', 'sitting', 'in', 'a', 'park', '.', '<eos>']
# reference
# [['two', 'guys', 'and', 'a', 'girl', 'smiling', '.', '<eos>']]
# candidate
# ['two', 'men', 'and', 'a', 'woman', 'are', 'a', '.', '<eos>']
# reference
# [['two', 'young', 'children', 'are', 'on', 'sand', '.', '<eos>']]
# candidate
# ['two', 'young', 'children', 'are', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'small', 'black', 'dog', 'jumping', 'over', 'gates', '<eos>']]
# candidate
# ['a', 'small', 'black', 'dog', 'is', 'running', 'across', 'the', 'water', '.', '<eos>']
# reference
# [['two', 'dogs', 'play', 'by', 'a', 'tree', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'playing', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'young', 'girl', 'swimming', 'in', 'a', 'pool', '<eos>']]
# candidate
# ['a', 'young', 'girl', 'is', 'in', 'a', 'pool', 'in', 'a', 'pool', '.', '<eos>']
# reference
# [['two', 'men', 'wearing', 'black', 'in', 'a', 'city', '<eos>']]
# candidate
# ['two', 'men', 'in', 'in', 'a', 'in', 'a', 'city', '.', '<eos>']
# reference
# [['a', 'man', 'cutting', 'branches', 'of', 'trees', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', '.', '<eos>']
# reference
# [['three', 'people', 'sit', 'in', 'a', 'cave', '.', '<eos>']]
# candidate
# ['three', 'people', 'are', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'guy', 'works', 'on', 'a', 'building', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'working', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'deer', 'jumps', 'a', 'fence', '.', '<eos>']]
# candidate
# ['a', 'brown', 'dog', 'jumps', 'over', 'a', 'ramp', '.', '<eos>']
# reference
# [['a', 'biker', 'jumps', 'an', 'obstacle', '.', '<eos>']]
# candidate
# ['a', 'skateboarder', 'is', 'jumping', 'a', 'a', '.', '<eos>']
# reference
# [['doctors', 'performing', 'some', 'type', 'of', 'surgery', '.', '<eos>']]
# candidate
# ['construction', 'workers', 'are', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['firemen', '<unk>', 'from', 'a', 'subway', 'station', '.', '<eos>']]
# candidate
# ['<unk>', 'are', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'using', 'electronic', 'equipment', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['a', 'man', 'on', 'his', 'wedding', 'day', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'on', 'his', 'cellphone', '.', '<eos>']
# reference
# [['dogs', 'run', 'at', 'a', 'dog', 'racetrack', '.', '<eos>']]
# candidate
# ['dogs', 'are', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'car', 'parked', 'at', 'the', 'beach', '.', '<eos>']]
# candidate
# ['a', 'mountain', 'on', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'child', 'is', 'splashing', 'in', 'the', 'water', '<eos>']]
# candidate
# ['a', 'child', 'is', 'in', 'the', 'water', '.', '<eos>']
# reference
# [['people', 'sit', 'inside', 'a', 'train', '.', '<eos>']]
# candidate
# ['people', 'are', 'sitting', 'in', 'a', 'park', '.', '<eos>']
# reference
# [['a', 'rock', 'concert', 'is', 'taking', 'place', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'of', 'a', '.', '<eos>']
# reference
# [['an', 'army', 'officer', 'is', 'inspecting', 'something', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['three', 'men', 'are', 'walking', 'up', 'hill', '.', '<eos>']]
# candidate
# ['three', 'men', 'are', 'walking', '.', '<eos>']
# reference
# [['a', 'woman', 'is', 'playing', 'volleyball', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'playing', 'the', '.', '<eos>']
# reference
# [['young', 'woman', 'climbing', 'rock', 'face', '<eos>']]
# candidate
# ['young', 'woman', 'is', 'on', 'on', 'the', '.', '.', '<eos>']
# reference
# [['two', 'men', 'wearing', 'hats', '.', '<eos>']]
# candidate
# ['two', 'men', 'wearing', 'black', 'shirts', '.', '<eos>']
# /anaconda3/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /anaconda3/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /anaconda3/lib/python3.6/site-packages/nltk/translate/bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# final tensor
# tensor([[ 4,  4,  4,  ...,  4, 63,  4],
#         [14, 35,  9,  ..., 14, 17,  6],
#         [10, 10, 22,  ..., 13,  6,  6],
#         ...,
#         [ 5,  3,  5,  ...,  5,  3,  5],
#         [ 3,  5,  3,  ...,  3,  3,  3],
#         [ 5,  3,  5,  ...,  3,  3,  3]])
# reference
# [['woman', 'selling', 'bags', 'of', 'fruit', 'on', 'a', 'sidewalk', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'on', 'a', 'street', 'with', 'with', 'graffiti', '.', '<eos>']
# reference
# [['a', 'dog', 'runs', 'outside', 'with', 'a', 'yellow', 'toy', '.', '<eos>']]
# candidate
# ['a', 'dog', 'is', 'with', 'a', 'red', 'toy', '.', '<eos>']
# reference
# [['a', 'man', 'wearing', 'an', 'orange', 'shirt', 'and', 'helmet', '.', '<eos>']]
# candidate
# ['a', 'man', 'wearing', 'a', 'red', 'and', 'and', 'a', 'hat', '.', '<eos>']
# reference
# [['guitar', 'player', 'performs', 'at', 'a', 'nightclub', 'red', 'guitar', '.', '<eos>']]
# candidate
# ['a', 'playing', 'on', 'a', 'stage', 'with', 'a', 'red', 'in', '.', '<eos>']
# reference
# [['a', 'man', 'standing', 'on', 'a', 'city', 'street', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'walking', 'a', 'street', 'street', '.', '<eos>']
# reference
# [['a', 'woman', 'draws', 'a', 'floral', 'design', 'on', 'a', 'clay', 'pot', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'a', 'a', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'men', 'playing', 'guitar', 'in', 'front', 'of', 'a', 'large', 'audience', '.', '<eos>']]
# candidate
# ['two', 'men', 'are', 'playing', 'a', 'a', 'in', 'front', 'of', 'a', 'building', '.']
# reference
# [['a', 'man', 'walking', 'in', 'front', 'of', 'a', 'colorful', 'wall', 'mural', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'walking', 'a', 'a', 'of', 'a', 'large', 'building', '.', '<eos>']
# reference
# [['a', 'woman', 'with', 'long', 'hair', 'is', 'at', 'a', 'graduation', 'ceremony', '.', '<eos>']]
# candidate
# ['a', 'woman', 'with', 'a', 'hair', 'is', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'black', 'is', 'holding', 'something', 'in', 'her', 'mouth', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'is', 'holding', 'a', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['6', 'people', 'are', 'gathered', 'around', 'to', 'eat', 'a', 'big', 'dinner', '.', '<eos>']]
# candidate
# ['people', 'are', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'girl', 'dressed', 'in', 'black', 'is', 'posing', 'for', 'the', 'camera', '.', '<eos>']]
# candidate
# ['a', 'girl', 'in', 'the', 'is', 'is', 'her', 'her', 'camera', '.', '<eos>']
# reference
# [['a', 'girl', 'in', 'a', 'sweater', 'is', 'blocking', 'the', '<unk>', '<unk>', '.', '<eos>']]
# candidate
# ['a', 'girl', 'in', 'a', 'pink', 'dress', 'is', 'her', 'her', '.', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'a', 'grassy', 'field', 'blows', 'on', 'a', 'dandelion', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['there', 'is', 'a', 'man', 'in', 'an', 'orange', 'shirt', 'playing', 'tennis', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'white', 'shirt', 'playing', 'the', 'drums', '.', '<eos>']
# reference
# [['kids', 'are', 'sitting', 'on', 'a', 'man', 'in', 'a', 'banana', 'suit', '.', '<eos>']]
# candidate
# ['children', 'are', 'on', 'a', 'a', 'in', 'a', 'park', '.', '<eos>']
# reference
# [['two', 'women', 'and', 'a', 'man', 'are', 'looking', 'at', 'a', 'book', '.', '<eos>']]
# candidate
# ['two', 'women', 'and', 'a', 'man', 'are', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'surfer', 'in', 'a', 'blue', 'swimsuit', 'is', 'riding', 'the', 'waves', '.', '<eos>']]
# candidate
# ['a', 'baseball', 'player', 'is', 'a', 'a', 'a', 'in', 'a', '.', '<eos>']
# reference
# [['two', 'men', 'in', 'army', 'uniforms', 'stand', 'next', 'to', 'a', 'woman', '.', '<eos>']]
# candidate
# ['two', 'men', 'in', 'black', 'stand', 'on', 'a', 'bench', '.', '<eos>']
# reference
# [['one', 'man', 'and', 'two', 'women', 'having', 'a', 'discussion', 'over', 'white', 'wine', '<eos>']]
# candidate
# ['a', 'man', 'and', 'two', 'women', 'are', 'and', 'and', '<unk>', '.', '<eos>']
# reference
# [['two', 'women', 'wearing', 'tank', 'tops', 'are', 'looking', 'at', 'the', 'camera', '.', '<eos>']]
# candidate
# ['two', 'women', 'in', 'in', 'the', 'the', 'the', 'camera', '.', '<eos>']
# reference
# [['a', 'man', 'wearing', 'a', 'all', 'black', 'and', 'playing', 'a', 'piano', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'in', 'black', 'playing', 'playing', 'guitar', '.', '<eos>']
# reference
# [['a', 'family', 'is', 'playing', 'on', 'the', 'beach', 'with', 'their', 'dog', '.', '<eos>']]
# candidate
# ['a', 'person', 'playing', 'playing', 'the', 'the', 'the', 'the', 'background', '.', '<eos>']
# reference
# [['the', 'woman', 'with', 'the', 'blue', 'shirt', 'is', 'holding', 'a', 'baby', '.', '<eos>']]
# candidate
# ['the', 'woman', 'in', 'a', 'black', 'shirt', 'is', 'holding', 'a', 'baby', '.', '<eos>']
# reference
# [['a', 'baby', 'in', 'a', 'christmas', 'outfit', 'looks', 'at', 'the', 'camera', '.', '<eos>']]
# candidate
# ['a', 'baby', 'in', 'the', 'the', 'is', 'is', 'her', 'her', 'camera', '.', '<eos>']
# reference
# [['a', 'man', 'on', 'a', 'tag', 'line', 'going', 'into', 'the', 'water', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'the', 'water', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'standing', 'in', 'front', 'of', 'an', 'igloo', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'standing', 'in', 'front', 'of', 'a', 'building', '.', '<eos>']
# reference
# [['a', 'boy', 'at', 'a', 'gun', 'range', 'aims', 'and', 'shoots', '.', '<eos>']]
# candidate
# ['a', 'boy', 'is', 'a', 'a', 'a', 'on', 'a', '.', '.', '<eos>']
# reference
# [['the', 'man', 'with', 'the', 'cane', 'is', 'on', 'a', 'walk', '.', '<eos>']]
# candidate
# ['the', 'man', 'in', 'the', 'air', 'is', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'throws', 'a', 'fishing', 'net', 'into', 'the', 'bay', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'into', 'the', 'air', '.', '<eos>']
# reference
# [['people', 'walking', 'down', 'the', 'street', 'with', 'a', 'street', 'vendor', '.', '<eos>']]
# candidate
# ['people', 'walking', 'down', 'a', 'street', 'street', 'with', 'a', '.', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'men', 'are', 'sitting', 'around', 'a', 'table', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'men', 'sitting', 'at', 'a', 'table', '.', '<eos>']
# reference
# [['a', 'young', 'man', 'and', 'women', 'near', 'a', 'large', 'metal', 'sculpture', '<eos>']]
# candidate
# ['a', 'young', 'man', 'and', 'a', 'woman', 'are', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'with', 'a', 'black', 'vest', 'holding', 'a', 'model', 'airplane', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'black', 'hat', 'is', 'holding', 'a', 'a', '.', '<eos>']
# reference
# [['three', 'young', 'girls', 'are', 'walking', 'together', 'down', 'the', 'sidewalk', '.', '<eos>']]
# candidate
# ['three', 'young', 'girls', 'are', 'walking', 'on', 'the', 'sidewalk', '.', '<eos>']
# reference
# [['asian', 'people', 'sitting', 'at', 'a', 'restaurant', 'with', 'yellow', 'chairs', '.', '<eos>']]
# candidate
# ['men', 'are', 'sitting', 'in', 'a', 'room', 'with', 'a', '.', '<eos>']
# reference
# [['people', 'jump', 'over', 'a', 'mountain', '<unk>', 'on', 'a', 'rope', '.', '<eos>']]
# candidate
# ['people', 'are', 'walking', 'a', 'a', 'path', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'children', 'looking', 'at', 'horses', 'through', 'a', 'small', 'fence', '.', '<eos>']]
# candidate
# ['two', 'boys', 'are', 'through', 'a', 'a', 'field', '.', '<eos>']
# reference
# [['several', 'people', 'sit', 'at', 'a', 'table', 'in', 'formal', 'clothing', '.', '<eos>']]
# candidate
# ['several', 'people', 'are', 'standing', 'in', 'a', 'table', '.', '<eos>']
# reference
# [['three', 'players', 'bring', 'a', 'team', 'opponent', 'to', 'the', 'ground', '.', '<eos>']]
# candidate
# ['three', 'players', 'players', 'to', 'the', 'the', 'ball', '.', '<eos>']
# reference
# [['three', 'young', 'sumo', 'wrestlers', 'standing', 'and', 'listening', 'to', 'an', '<unk>', '<eos>']]
# candidate
# ['three', 'young', 'boys', 'are', 'standing', 'a', 'a', '<unk>', '.', '<eos>']
# reference
# [['the', 'yellow', 'dog', 'is', 'carrying', 'a', 'stick', 'by', 'water', '.', '<eos>']]
# candidate
# ['the', 'brown', 'dog', 'is', 'running', 'through', 'the', 'snow', '.', '<eos>']
# reference
# [['multiple', 'people', 'in', 'a', 'park', 'eating', 'at', 'a', 'picnic', 'table', '<eos>']]
# candidate
# ['people', 'are', 'a', 'a', 'in', 'a', 'city', 'day', '.', '<eos>']
# reference
# [['a', 'man', 'playing', 'an', 'instrument', 'next', 'to', 'a', 'tree', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'playing', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['men', 'in', 'cowboy', 'hats', 'stand', 'around', 'at', 'a', 'rodeo', '.', '<eos>']]
# candidate
# ['men', 'in', 'in', 'are', 'standing', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'tribal', 'group', 'filling', 'water', '<unk>', 'in', 'the', 'desert', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'men', 'are', 'in', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'woman', 'is', 'laying', 'down', 'on', 'a', 'sofa', 'laughing', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'on', 'a', 'bench', 'bench', '.', '<eos>']
# reference
# [['a', 'cook', 'is', 'posing', 'for', 'a', 'camera', 'while', 'cooking', '.', '<eos>']]
# candidate
# ['a', 'photographer', 'is', 'the', 'the', 'camera', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'martial', 'arts', 'uniform', 'in', 'midair', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'air', 'in', 'the', 'air', '.', '<eos>']
# reference
# [['three', 'young', 'children', 'are', 'walking', 'through', 'a', 'grassy', 'yard', '.', '<eos>']]
# candidate
# ['three', 'young', 'children', 'are', 'walking', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'woman', 'wearing', 'similar', 'shirts', 'walk', 'to', 'the', 'left', '.', '<eos>']]
# candidate
# ['two', 'women', 'in', 'black', 'shirts', 'are', 'walking', 'the', '.', '.', '<eos>']
# reference
# [['two', 'dogs', 'are', '<unk>', 'each', 'other', 'nose', 'to', 'nose', '.', '<eos>']]
# candidate
# ['two', 'dogs', 'are', 'on', 'the', '<unk>', '.', '<eos>']
# reference
# [['a', 'railroad', 'work', 'crew', 'performs', 'maintenance', 'on', 'railroad', 'tracks', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'are', 'on', 'on', 'the', '.', '.', '<eos>']
# reference
# [['the', 'group', 'of', 'people', 'are', 'all', 'covered', 'by', 'umbrellas', '.', '<eos>']]
# candidate
# ['people', 'people', 'standing', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'black', 'dog', 'is', 'retrieving', 'a', 'ball', 'in', 'water', '.', '<eos>']]
# candidate
# ['a', 'black', 'dog', 'is', 'running', 'through', 'the', 'water', 'with', 'a', 'mouth', '.']
# reference
# [['a', 'girl', 'wearing', 'a', 'life', 'vest', 'floats', 'in', 'water', '.', '<eos>']]
# candidate
# ['a', 'girl', 'in', 'a', 'bathing', 'bathing', 'suit', 'in', 'the', 'water', '.', '<eos>']
# reference
# [['two', 'children', 'sit', 'side', 'by', 'side', 'while', 'eating', 'a', 'treat', '.', '<eos>']]
# candidate
# ['two', 'children', 'are', 'sitting', 'and', 'drinking', 'food', '.', '<eos>']
# reference
# [['a', 'guard', 'is', 'on', 'the', 'look', 'out', 'while', 'on', '<unk>', '.', '<eos>']]
# candidate
# ['a', 'baseball', 'player', 'is', 'his', 'his', 'and', 'and', 'his', '.', '.', '<eos>']
# reference
# [['a', 'busy', 'day', 'for', 'citizens', 'at', 'a', 'local', 'city', 'court', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'on', 'a', 'sunny', 'day', '.', '<eos>']
# reference
# [['a', 'teenage', 'girl', 'is', 'carrying', 'a', 'guitar', 'in', 'the', 'woods', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'walking', 'in', 'the', 'snow', '.', '<eos>']
# reference
# [['three', 'boys', 'are', 'playing', 'with', '<unk>', 'and', 'buckets', 'of', 'water', '.', '<eos>']]
# candidate
# ['three', 'boys', 'playing', 'with', 'a', 'and', 'and', '.', '<eos>']
# reference
# [['asian', 'woman', 'wearing', 'a', 'sunhat', 'while', 'riding', 'a', 'bike', '.', '<eos>']]
# candidate
# ['this', 'woman', 'is', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'selling', 'snacks', 'at', 'a', 'sporting', 'event', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['these', 'people', 'are', 'climbing', 'the', 'steps', 'to', 'go', 'the', 'mountain', '<eos>']]
# candidate
# ['many', 'people', 'are', 'walking', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['two', 'people', 'are', 'spending', 'good', 'time', 'in', 'their', 'boat', '.', '<eos>']]
# candidate
# ['two', 'people', 'are', 'on', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['people', 'on', 'laptops', 'in', 'front', 'pf', 'a', 'large', 'window', '.', '<eos>']]
# candidate
# ['people', 'in', 'a', 'of', 'a', 'building', 'in', 'front', 'of', 'a', 'crowd', '.']
# reference
# [['two', 'woman', 'are', 'mud', 'wrestling', 'in', 'a', 'kiddie', 'pool', '.', '<eos>']]
# candidate
# ['two', 'women', 'are', 'in', 'a', 'a', 'in', 'a', '.', '.', '<eos>']
# reference
# [['a', 'young', 'boy', 'is', 'hanging', 'onto', 'a', 'clothing', 'rack', '.', '<eos>']]
# candidate
# ['a', 'little', 'boy', 'is', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'girl', 'is', 'playing', 'in', 'the', 'fountain', 'fully', 'clothed', '.', '<eos>']]
# candidate
# ['a', 'girl', 'playing', 'in', 'the', 'the', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'man', 'sells', 'potatoes', 'to', 'a', 'group', 'of', 'people', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'men', 'breakdancing', ',', 'with', 'a', 'crowd', 'looking', 'on', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'men', 'men', 'are', 'walking', 'together', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'women', 'are', 'playing', 'musical', 'instruments', 'together', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'men', 'playing', 'on', 'on', 'stage', '.', '<eos>']
# reference
# [['the', 'white', 'dog', 'is', 'running', 'in', 'the', 'shallow', 'water', '.', '<eos>']]
# candidate
# ['the', 'black', 'dog', 'is', 'running', 'the', 'water', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['three', 'farmers', 'harvest', 'rice', 'out', 'in', 'a', 'rice', 'field', '.', '<eos>']]
# candidate
# ['three', '<unk>', 'players', 'are', 'in', 'the', 'field', '.', '<eos>']
# reference
# [['a', 'man', 'on', 'a', 'bicycle', 'rides', 'on', 'a', 'mountain', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'riding', 'a', 'bicycle', 'on', 'a', 'sidewalk', '.', '<eos>']
# reference
# [['a', 'choir', 'group', 'is', 'gathered', 'together', 'in', 'a', 'church', '.', '<eos>']]
# candidate
# ['a', 'construction', 'worker', 'in', 'a', 'crowd', '.', '<eos>']
# reference
# [['a', 'little', 'kid', 'is', 'walking', 'next', 'to', 'red', 'banners', '.', '<eos>']]
# candidate
# ['a', 'young', 'child', 'is', 'in', 'front', 'of', 'a', 'red', '.', '.', '<eos>']
# reference
# [['the', 'brown', 'dog', 'is', 'standing', 'on', 'the', 'sandy', 'beach', '.', '<eos>']]
# candidate
# ['the', 'black', 'dog', 'is', 'on', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['six', 'people', 'ride', 'mountain', 'bikes', 'through', 'a', 'jungle', 'environment', '.', '<eos>']]
# candidate
# ['five', 'people', 'are', 'walking', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'wearing', 'sunglasses', 'is', 'riding', 'a', 'scooter', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'helmet', 'is', 'on', 'a', 'sidewalk', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'talking', 'on', 'a', 'cellphone', 'outside', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'playing', 'an', '<unk>', 'in', 'a', 'concert', '<eos>']]
# candidate
# ['a', 'man', 'is', 'playing', 'a', 'a', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'technician', 'preparing', 'a', 'sample', 'in', 'the', 'lab', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', 'a', 'a', 'in', 'a', '.', '<eos>']
# reference
# [['four', 'children', 'practice', 'karate', 'while', 'two', 'adults', 'watch', '.', '<eos>']]
# candidate
# ['four', 'children', 'are', 'playing', 'while', 'two', 'other', 'children', 'are', '.', '<eos>']
# reference
# [['a', 'blond', 'girl', 'sleeps', 'on', 'a', 'brown', 'couch', '.', '<eos>']]
# candidate
# ['a', 'young', 'girl', 'is', 'on', 'a', 'red', 'bench', '.', '<eos>']
# reference
# [['two', 'young', 'men', 'play', 'electric', 'guitars', 'on', 'stage', '.', '<eos>']]
# candidate
# ['two', 'young', 'men', 'playing', 'on', 'a', 'stage', 'on', 'stage', '.', '<eos>']
# reference
# [['a', 'man', 'riding', 'his', 'bike', 'up', 'the', 'ramp', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'riding', 'the', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'young', 'brunette', 'woman', 'eating', 'and', 'drinking', 'something', '.', '<eos>']]
# candidate
# ['a', 'young', 'woman', 'with', 'glasses', 'is', 'her', 'her', '.', '<eos>']
# reference
# [['boy', 'in', 'sunglasses', 'is', 'running', 'behind', 'a', 'fair', '.', '<eos>']]
# candidate
# ['a', 'young', 'boy', 'is', 'walking', 'in', 'the', 'street', '.', '<eos>']
# reference
# [['a', 'man', 'fixing', 'a', 'little', 'girl', "'s", 'bicycle', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['an', 'older', 'man', 'in', 'glasses', 'is', 'preparing', 'meat', '.', '<eos>']]
# candidate
# ['older', 'man', 'with', 'a', 'beard', 'is', 'his', '.', '.', '<eos>']
# reference
# [['a', '<unk>', 'brown', 'dog', 'walking', 'on', 'the', 'grass', '.', '<eos>']]
# candidate
# ['a', 'black', 'and', 'white', 'dog', 'is', 'running', 'the', 'the', 'grass', '.', '<eos>']
# reference
# [['a', 'man', 'with', 'graying', 'hair', '<unk>', 'his', 'beard', '.', '<eos>']]
# candidate
# ['a', 'man', 'with', 'a', '<unk>', '<unk>', 'his', 'hand', '.', '<eos>']
# reference
# [['the', 'boy', 'jumps', 'onto', 'his', 'soccer', 'player', 'brother', '.', '<eos>']]
# candidate
# ['a', 'boy', 'is', 'jumping', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['fans', 'cheer', 'as', 'the', 'band', 'plays', 'a', 'song', '.', '<eos>']]
# candidate
# ['a', 'are', 'playing', 'the', 'playing', 'a', 'game', 'and', 'a', '.', '<eos>']
# reference
# [['many', 'people', 'are', 'sitting', 'around', 'a', 'tent', 'outside', '.', '<eos>']]
# candidate
# ['people', 'people', 'are', 'sitting', 'around', 'a', 'table', '.', '<eos>']
# reference
# [['a', '<unk>', 'relaxes', 'and', 'waits', 'at', 'an', 'airport', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'and', 'a', 'a', 'a', 'on', 'a', 'stage', '.', '<eos>']
# reference
# [['a', 'dog', 'drinks', 'water', 'outside', 'on', 'the', 'grass', '.', '<eos>']]
# candidate
# ['a', 'dog', 'is', 'on', 'the', 'grass', 'in', 'the', 'snow', '.', '<eos>']
# reference
# [['two', 'men', 'and', 'a', 'lady', 'are', 'standing', 'outside', '.', '<eos>']]
# candidate
# ['two', 'men', 'and', 'a', 'woman', 'are', 'standing', 'in', 'a', '.', '.', '<eos>']
# reference
# [['two', 'people', 'riding', 'bikes', 'through', 'a', 'mountainous', 'region', '.', '<eos>']]
# candidate
# ['two', 'people', 'are', 'walking', 'a', 'a', 'path', '.', '<eos>']
# reference
# [['a', 'young', 'lady', 'in', 'white', 'holding', 'a', 'tennis', 'racket', '<eos>']]
# candidate
# ['a', 'young', 'woman', 'in', 'a', 'pink', 'shirt', 'is', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'is', 'grilling', 'out', 'in', 'his', 'backyard', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'talking', 'at', 'tables', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'are', 'gathered', 'around', '.', '<eos>']
# reference
# [['a', 'yellow', 'bulldozer', 'working', 'to', 'move', 'dirt', '.', '<eos>']]
# candidate
# ['a', 'baseball', 'player', 'is', 'a', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'village', 'women', 'gathered', 'in', 'dance', '<eos>']]
# candidate
# ['a', 'group', 'of', 'young', 'people', 'are', 'gathered', 'around', '.', '<eos>']
# reference
# [['several', 'men', 'standing', 'around', 'an', 'antique', 'race', 'car', '<eos>']]
# candidate
# ['several', 'men', 'are', 'in', 'a', 'a', 'of', 'a', '.', '<eos>']
# reference
# [['a', 'crowd', 'on', 'a', 'busy', 'daytime', 'street', '.', '<eos>']]
# candidate
# ['a', 'crowd', 'of', 'people', 'walking', 'on', 'a', 'city', 'street', '.', '<eos>']
# reference
# [['a', 'dog', 'jumps', 'over', 'an', 'obstacle', 'outside', '.', '<eos>']]
# candidate
# ['a', 'dog', 'jumps', 'through', 'a', 'air', '.', '<eos>']
# reference
# [['a', 'view', 'of', 'a', 'crowded', 'city', 'street', '.', '<eos>']]
# candidate
# ['a', 'crowd', 'of', 'people', 'walking', 'in', 'the', 'street', '.', '<eos>']
# reference
# [['a', 'little', 'girl', 'opening', 'a', 'christmas', 'present', '.', '<eos>']]
# candidate
# ['a', 'little', 'girl', 'is', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'indian', 'men', 'participating', 'in', 'a', 'ceremony', '.', '<eos>']]
# candidate
# ['two', 'men', 'men', 'are', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'toddler', 'is', 'cooking', 'with', 'another', 'person', '.', '<eos>']]
# candidate
# ['a', 'young', 'child', 'is', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['three', 'woman', 'bouncing', 'on', 'balls', 'in', 'the', 'grass', '.', '<eos>']]
# candidate
# ['three', 'women', 'are', 'in', 'the', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'lady', 'dressed', 'in', 'blue', 'running', 'a', 'marathon', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'is', 'walking', 'through', 'a', 'city', '.', '<eos>']
# reference
# [['several', 'football', 'players', 'on', 'a', 'field', 'in', 'action', '.', '<eos>']]
# candidate
# ['several', 'people', 'are', 'in', 'a', 'field', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['this', 'is', 'a', 'clown', 'at', 'an', 'elementary', 'school', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'in', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'gymnast', 'is', 'being', '<unk>', 'at', '<unk>', 'event', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'of', 'a', 'a', 'a', '<unk>', '.', '<eos>']
# reference
# [['a', 'young', 'girl', 'sitting', 'on', 'a', 'wooden', 'chair', '.', '<eos>']]
# candidate
# ['a', 'young', 'girl', 'is', 'sitting', 'on', 'a', 'bench', '.', '<eos>']
# reference
# [['some', 'leaping', 'over', 'a', 'high', 'bar', 'in', '<unk>', '.', '<eos>']]
# candidate
# ['a', 'person', 'is', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['busy', 'asian', 'mall', 'with', 'paper', 'lanterns', 'and', 'shoppers', '.', '<eos>']]
# candidate
# ['<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'and', '.', '.', '<eos>']
# reference
# [['woman', 'in', 'a', 'pink', 'shirt', 'and', 'wearing', 'glasses', '.', '<eos>']]
# candidate
# ['woman', 'in', 'a', 'black', 'shirt', 'is', 'a', 'a', '.', '<eos>']
# reference
# [['people', 'on', 'the', 'sideline', 'of', 'a', 'soccer', 'match', '.', '<eos>']]
# candidate
# ['people', 'are', 'in', 'a', 'a', 'in', 'a', '.', '.', '<eos>']
# reference
# [['man', 'jumping', 'with', 'a', 'rock', 'formation', 'in', 'background', '.', '<eos>']]
# candidate
# ['man', 'is', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['two', 'men', 'selling', 'fruit', 'at', 'a', 'fruit', 'market', '.', '<eos>']]
# candidate
# ['two', 'men', 'are', 'on', 'a', 'a', 'on', 'a', '.', '.', '<eos>']
# reference
# [['a', 'young', 'lady', 'doing', 'yoga', 'on', 'the', 'beach', '.', '<eos>']]
# candidate
# ['a', 'young', 'woman', 'is', 'walking', 'the', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'woman', 'wearing', 'a', 'hat', 'with', 'making', 'bread', '.', '<eos>']]
# candidate
# ['a', 'woman', 'with', 'a', 'red', 'hat', 'is', 'her', '.', '.', '<eos>']
# reference
# [['children', 'jump', 'off', 'the', 'edge', 'into', 'a', 'pool', '.', '<eos>']]
# candidate
# ['children', 'are', 'in', 'a', 'a', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['bicyclist', 'in', 'racing', 'gear', 'rides', 'through', 'forest', 'area', '.', '<eos>']]
# candidate
# ['a', 'in', 'in', 'the', 'gear', 'is', 'a', 'a', 'a', '.', '<eos>']
# final tensor
# tensor([[ 4,  4, 63,  ...,  7,  4,  7],
#         [ 9, 38, 17,  ..., 34, 24, 25],
#         [ 6, 12, 18,  ..., 10, 12, 35],
#         ...,
#         [ 3,  5,  3,  ...,  3,  5,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])
# reference
# [['a', 'man', 'in', 'a', 'suit', 'is', 'sitting', 'at', 'a', 'bus', 'stop', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'suit', 'is', 'sitting', 'on', 'a', 'bench', '.', '<eos>']
# reference
# [['a', 'group', 'of', 'people', 'walk', 'down', 'the', 'street', 'in', 'the', 'sun', '.', '<eos>']]
# candidate
# ['a', 'group', 'of', 'people', 'walking', 'down', 'the', 'street', '.', '<eos>']
# reference
# [['children', 'fight', 'to', 'win', 'a', 'tug', '-', 'of', '-', 'war', 'battle', '.', '<eos>']]
# candidate
# ['children', 'are', 'to', 'to', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['a', 'black', 'and', 'white', 'dog', 'is', 'playing', 'with', 'a', 'white', 'ball', '.', '<eos>']]
# candidate
# ['a', 'black', 'and', 'white', 'dog', 'playing', 'with', 'a', 'ball', 'ball', '.', '<eos>']
# reference
# [['a', 'boy', 'with', 'blue', 'and', 'yellow', 'rain', 'boots', 'runs', 'on', 'dirt', '.', '<eos>']]
# candidate
# ['a', 'boy', 'in', 'red', 'is', 'running', 'through', 'the', 'snow', '.', '<eos>']
# reference
# [['a', 'construction', 'worker', 'is', 'driving', 'heavy', 'equipment', 'at', 'a', 'work', 'site', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', '<unk>', '<unk>', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'hockey', 'game', 'is', 'being', 'played', 'with', 'lots', 'of', 'people', 'watching', 'it', '.', '<eos>']]
# candidate
# ['a', '<unk>', 'is', 'in', 'front', 'of', 'a', 'large', '.', '.', '<eos>']
# reference
# [['a', 'long', '-', 'haired', ',', 'male', 'musician', 'is', 'playing', 'on', 'a', 'piano', '.', '<eos>']]
# candidate
# ['a', 'man', 'with', 'a', 'hair', 'playing', 'playing', 'guitar', '.', '<eos>']
# reference
# [['a', 'little', 'girl', 'running', 'at', 'on', 'the', 'shore', 'of', 'a', 'beach', '.', '<eos>']]
# candidate
# ['a', 'little', 'girl', 'is', 'walking', 'down', 'a', 'street', '.', '<eos>']
# ...
# candidate
# ['a', 'child', 'in', 'a', 'blue', 'jacket', 'is', 'standing', 'in', 'a', 'of', 'a', 'a', 'with', 'a', 'large', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['four', 'men', ',', 'three', 'of', 'whom', 'are', 'wearing', 'prayer', 'caps', ',', 'are', 'sitting', 'on', 'a', 'blue', 'and', 'olive', 'green', 'patterned', 'mat', '.', '<eos>']]
# candidate
# ['four', 'men', 'men', 'men', ',', 'one', 'wearing', 'blue', 'and', 'and', ',', 'are', 'standing', 'on', 'a', 'a', 'and', '.', '<eos>']
# reference
# [['two', 'girls', '(', 'one', 'dressed', 'in', 'blue', ',', 'and', 'one', 'dressed', 'in', 'pink', ')', 'are', 'racing', 'one', 'another', 'on', 'rollerskates', '.', '<eos>']]
# candidate
# ['two', 'girls', 'in', 'black', 'and', 'and', 'and', 'and', 'and', 'a', 'are', 'are', 'walking', 'down', 'the', 'street', '.', '<eos>']
# reference
# [['an', 'employee', 'is', 'handing', 'a', 'woman', 'a', 'bag', 'while', 'she', 'is', 'browsing', 'through', 'fish', 'on', 'ice', 'at', 'a', 'street', 'market', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'while', 'a', 'woman', 'on', 'a', 'on', 'the', '.', '.', '<eos>']
# reference
# [['two', 'children', ',', 'a', 'boy', 'in', 'a', 'yellow', 'shirt', 'and', 'a', 'girl', 'in', 'blue', 'and', 'white', 'stripes', ',', 'swinging', '.', '<eos>']]
# candidate
# ['two', 'boys', ',', 'one', 'in', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['shirtless', 'guy', 'staring', 'off', 'in', 'the', 'distance', 'while', 'three', 'woman', 'are', 'walking', 'past', 'a', 'crowd', 'sitting', 'outside', 'a', 'cafe', '.', '<eos>']]
# candidate
# ['a', 'man', 'man', 'is', 'standing', 'in', 'front', 'of', 'a', 'large', 'of', 'a', 'while', 'a', 'group', 'of', 'people', 'in', 'front', 'of', 'a', 'crowd', '.', '<eos>']
# reference
# [['a', 'female', 'performer', 'with', 'a', 'violin', 'plays', 'on', 'a', 'street', 'while', 'a', 'woman', 'with', 'a', 'blue', 'guitar', 'looks', 'on', '.', '<eos>']]
# candidate
# ['a', 'street', 'with', 'with', 'a', 'band', 'on', 'stage', 'with', 'a', 'woman', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'small', 'white', 'car', 'is', 'on', 'the', 'train', 'tracks', 'and', 'may', 'or', 'may', 'not', 'have', 'been', 'hit', 'by', 'the', 'train', 'behind', 'it', '.', '<eos>']]
# candidate
# ['a', 'small', 'white', 'dog', 'is', 'standing', 'on', 'the', 'beach', 'with', 'his', 'mouth', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['an', 'african', '-', 'american', 'boy', 'wearing', 'blue', 'shorts', ',', 'a', 'black', 'and', 'red', 'shirt', ',', 'and', 'white', 'sneakers', ',', 'is', 'playing', 'tennis', '.', '<eos>']]
# candidate
# ['a', 'young', 'boy', 'in', 'a', 'white', 'shirt', 'and', 'blue', 'shorts', 'and', 'a', 'black', 'is', 'playing', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'driving', 'a', 'four', 'wheeled', 'vehicle', 'with', 'four', 'passengers', 'riding', 'on', 'the', 'front', 'and', 'a', 'man', 'sitting', 'sideways', 'on', 'the', 'back', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'with', 'a', 'guitar', 'with', 'his', 'head', 'while', 'another', 'man', 'in', 'a', '.', '<eos>']
# reference
# [['riot', 'police', 'are', 'standing', 'in', 'the', 'background', 'while', 'a', 'young', 'man', 'with', 'a', 'red', 'scarf', 'covering', 'his', 'face', 'is', 'walking', '.', '<eos>']]
# candidate
# ['this', 'is', 'is', 'standing', 'in', 'a', 'field', ',', 'a', 'a', 'man', 'in', 'a', 'blue', 'shirt', 'is', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['two', 'people', 'wearing', 'odd', '<unk>', '-', 'like', 'costumes', ',', 'one', 'blue', 'and', 'one', 'purple', ',', 'are', 'standing', 'in', 'a', 'road', '.', '<eos>']]
# candidate
# ['two', 'people', 'in', 'white', 'uniforms', 'and', 'a', ',', 'and', ',', 'and', 'a', 'stand', 'on', 'a', 'street', 'street', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'a', 'mostly', 'black', 'outfit', 'and', 'white', 'helmet', 'riding', 'a', 'bike', 'with', 'blurred', 'trees', 'in', 'the', 'background', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'black', 'dress', 'with', 'a', 'red', 'walks', 'in', 'the', 'air', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'young', 'lady', 'and', 'man', 'dressed', 'in', '<unk>', 'costume', 'wielding', 'sticks', 'with', 'a', 'group', 'of', 'people', 'in', 'the', 'background', '.', '<eos>']]
# candidate
# ['a', 'young', 'woman', 'and', 'a', 'young', 'boy', 'in', 'a', 'in', 'front', 'of', 'a', 'large', 'building', 'with', 'a', 'in', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'child', 'leans', 'over', 'a', 'display', 'made', 'up', 'of', 'blue', 'and', 'yellow', 'plastic', ',', 'while', 'an', 'adult', 'looks', 'on', '.', '<eos>']]
# candidate
# ['a', 'child', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'while', 'a', 'a', 'a', 'while', 'another', 'man', 'watches', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'black', 'shirt', 'sitting', 'at', 'a', 'table', 'with', 'an', 'open', 'apple', 'laptop', 'in', 'front', 'of', 'him', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'black', 'shirt', 'is', 'sitting', 'at', 'a', 'table', 'in', 'front', 'of', 'a', 'large', 'with', 'a', '.', '<eos>']
# reference
# [['the', 'girl', 'in', 'yellow', 'is', 'laughing', 'at', 'the', 'girl', 'wearing', 'orange', 'whilst', 'being', 'watched', 'by', 'the', 'girl', 'in', 'blue', '.', '<eos>']]
# candidate
# ['the', 'girl', 'in', 'the', 'is', 'is', 'holding', 'her', 'her', 'her', 'her', 'in', 'in', 'a', 'pink', 'dress', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'a', 'red', 'shirt', 'is', 'riding', 'an', 'all', 'white', 'horse', 'that', 'is', 'galloping', 'along', 'the', 'trees', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'blue', 'shirt', 'is', 'riding', 'a', 'bicycle', 'on', 'a', 'a', 'in', 'the', 'air', '.', '<eos>']
# reference
# [['a', 'woman', 'is', 'standing', 'in', 'a', 'green', 'field', 'holding', 'a', 'white', 'dog', 'and', 'pointing', 'at', 'a', 'brown', 'dog', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'on', 'a', 'blue', 'dog', 'with', 'a', 'dog', 'dog', 'on', 'a', 'dog', 'on', 'a', 'brown', 'dog', '.', '<eos>']
# reference
# [['a', 'mother', 'teaches', 'her', 'two', 'young', 'boys', 'to', 'fish', 'off', 'of', 'a', 'rocky', 'coast', 'into', 'very', 'blue', 'water', '.', '<eos>']]
# candidate
# ['a', 'large', 'couple', 'of', 'two', 'men', 'are', 'walking', 'a', 'a', 'with', 'a', 'large', 'with', 'with', 'trees', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'a', 'red', 'bikini', 'jumping', 'to', 'hit', 'a', 'ball', 'while', 'playing', 'volleyball', 'at', 'a', 'beach', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'to', 'hit', 'a', 'ball', 'ball', 'on', 'the', 'air', '.', '<eos>']
# reference
# [['a', 'girl', 'sits', 'on', 'a', 'decorated', 'bike', 'with', 'a', 'younger', 'boy', 'while', 'another', 'girl', 'takes', 'a', 'picture', '.', '<eos>']]
# candidate
# ['a', 'girl', 'is', 'on', 'a', 'a', 'while', 'a', 'boy', 'boy', 'on', 'a', 'cellphone', 'while', 'a', 'man', "'s", 'head', '.', '<eos>']
# reference
# [['a', 'woman', 'takes', 'a', 'picture', 'of', 'a', 'baby', 'wearing', 'a', 'pink', 'hat', 'while', 'a', 'man', 'carries', 'her', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'woman', 'in', 'a', 'gray', 'sweater', 'and', 'black', 'baseball', 'cap', 'is', 'standing', 'in', 'line', 'at', 'a', 'shop', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'red', 'jacket', 'and', 'a', 'hat', 'and', 'a', 'is', 'standing', 'in', 'a', 'city', 'in', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'child', 'in', 'blue', 'and', 'a', 'child', 'in', 'white', 'stand', 'on', 'a', 'short', 'concrete', 'wall', 'by', 'a', 'stream', '.', '<eos>']]
# candidate
# ['a', 'child', 'in', 'a', 'blue', 'and', 'and', 'a', 'blue', 'shirt', 'is', 'standing', 'on', 'a', 'sidewalk', 'next', 'to', 'a', 'large', '.', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'pink', 'shirt', 'is', 'sitting', 'in', 'the', 'grass', 'and', 'a', 'ball', 'is', 'in', 'the', 'air', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'blue', 'shirt', 'is', 'on', 'the', 'ground', 'with', 'a', 'skateboard', 'in', 'the', 'air', '.', '<eos>']
# reference
# [['a', 'woman', 'sitting', 'on', 'a', 'very', 'large', 'rock', 'smiling', 'at', 'the', 'camera', 'with', 'trees', 'in', 'the', 'background', '.', '<eos>']]
# candidate
# ['a', 'woman', 'is', 'standing', 'in', 'the', 'street', 'of', 'a', 'a', 'while', 'holding', 'a', 'a', 'and', 'the', 'the', 'the', 'the', '.', '<eos>']
# reference
# [['three', 'men', 'in', 'red', 'and', 'white', 'striped', 'shirts', ',', 'white', 'pants', ',', 'and', 'black', 'hats', 'hold', 'flags', '.', '<eos>']]
# candidate
# ['three', 'men', 'in', 'black', 'shirts', 'and', 'white', 'shirts', 'and', 'white', 'and', 'and', 'white', 'and', 'white', 'shirts', 'are', '.', '<eos>']
# reference
# [['a', 'navy', 'walking', 'wearing', 'a', 'black', 'coat', 'and', 'pants', 'on', 'the', 'stairs', 'as', 'camera', 'focuses', 'on', 'the', 'dog', '<eos>']]
# candidate
# ['a', 'baseball', 'player', 'in', 'a', 'white', 'and', 'white', 'hat', 'is', 'on', 'the', 'ground', 'while', 'another', 'boy', 'is', 'on', 'his', 'head', '.', '<eos>']
# reference
# [['an', 'oriental', 'person', 'in', 'a', 'red', 'shirt', 'and', 'black', 'pants', 'crouching', 'over', 'a', 'purse', 'on', 'concrete', '.', '<eos>']]
# candidate
# ['a', 'person', 'dressed', 'in', 'a', 'red', 'and', 'white', 'shirt', 'and', 'blue', 'pants', 'is', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['two', 'young', 'men', 'riding', 'on', 'a', 'very', 'small', 'horse', '-', 'drawn', 'wagon', 'full', 'of', 'potatoes', '.', '<eos>']]
# candidate
# ['two', 'young', 'men', 'are', 'walking', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['a', '<unk>', 'is', 'pretending', 'to', 'keep', 'his', 'hands', 'warm', 'but', '<unk>', 'he', 'is', 'smoking', '<unk>', '.', '<eos>']]
# candidate
# ['a', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'black', 'shirt', 'and', 'jeans', 'standing', 'on', 'the', 'sidewalk', 'looking', 'at', 'the', 'camera', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'white', 'shirt', 'and', 'jeans', 'is', 'standing', 'the', 'street', 'while', 'holding', 'his', 'hands', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'yellow', 'coat', 'tends', 'a', 'fire', ',', 'a', 'boy', 'in', 'a', 'parka', 'watches', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'blue', 'jacket', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# reference
# [['three', 'people', 'sit', 'at', 'a', 'picnic', 'table', 'outside', 'of', 'a', 'building', 'painted', 'like', 'a', 'union', 'jack', '.', '<eos>']]
# candidate
# ['three', 'people', 'standing', 'in', 'a', 'of', 'a', 'building', 'that', 'has', 'a', '<unk>', 'that', 'says', '"', '.', '<eos>']
# reference
# [['a', 'woman', 'and', 'a', 'child', 'embrace', 'while', 'the', 'child', '<unk>', 'what', 'they', 'have', 'been', 'making', '.', '<eos>']]
# candidate
# ['a', 'woman', 'and', 'a', 'child', 'are', 'a', 'a', 'a', 'to', 'be', 'the', 'to', 'be', 'a', '.', '<eos>']
# reference
# [['a', 'man', 'in', 'a', 'black', 'and', 'white', 'jersey', 'is', 'holding', 'yellow', 'ski', 'poles', 'and', 'preparing', 'to', 'take', 'off', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'holding', 'a', '<unk>', 'while', 'he', 'is', 'to', 'the', 'the', '.', '<eos>']
# reference
# [['a', 'shirtless', 'man', 'in', 'black', 'shorts', 'is', 'standing', 'on', 'the', 'rocky', 'shore', 'to', 'a', 'large', 'body', 'of', 'water', '.', '<eos>']]
# candidate
# ['a', 'man', 'in', 'a', 'blue', 'shirt', 'is', 'standing', 'in', 'a', 'of', 'a', 'large', 'building', 'in', 'front', 'of', 'a', 'large', 'building', '.', '<eos>']
# reference
# [['a', 'woman', 'wearing', 'a', 'black', 'tank', 'top', 'and', 'a', 'cross', 'necklace', 'stares', 'off', 'into', 'the', 'distance', 'near', 'sunset', '.', '<eos>']]
# candidate
# ['a', 'woman', 'in', 'a', 'red', 'dress', 'with', 'a', '<unk>', 'is', 'is', 'her', 'her', 'in', 'the', 'middle', 'of', 'the', 'street', '.', '<eos>']
# reference
# [['an', 'overweight', 'woman', 'with', 'long', 'black', 'hair', 'in', 'a', 'pink', 'shirt', 'with', 'a', 'name', 'tag', 'is', 'applying', 'lipstick', '.', '<eos>']]
# candidate
# ['a', 'woman', 'woman', 'woman', 'with', 'long', 'hair', 'hair', 'with', 'a', 'black', 'shirt', 'with', 'a', 'hair', 'is', 'on', 'her', '.', '.', '<eos>']
# reference
# [['a', 'man', 'performing', 'a', 'trick', 'on', 'a', 'bicycle', 'by', 'standing', 'on', 'the', 'pedals', 'while', 'the', 'bike', 'is', 'upright', '.', '<eos>']]
# candidate
# ['a', 'man', 'is', 'a', 'a', 'a', 'a', 'on', 'his', 'head', 'on', 'the', 'ground', '.', '<eos>']
# reference
# [['a', 'boy', 'in', 'a', 'black', 'shirt', 'and', 'red', '<unk>', 'hanging', 'upside', 'down', 'while', 'other', 'people', 'look', 'on', '.', '<eos>']]
# candidate
# ['a', 'boy', 'in', 'a', 'white', 'shirt', 'and', 'blue', 'pants', 'is', 'a', 'while', 'people', 'people', 'watch', 'while', 'people', 'watch', '.', '<eos>']
# reference
# [['a', 'smiling', 'man', 'wearing', 'a', 'backpack', 'holds', 'his', 'fists', 'up', 'in', 'front', 'of', 'a', 'boy', 'in', 'glasses', '.', '<eos>']]
# candidate
# ['a', 'bald', 'man', 'with', 'a', 'hair', 'is', 'a', 'a', 'a', 'with', 'a', 'in', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['three', 'men', 'are', 'standing', 'on', 'a', 'stage', ',', 'one', 'is', 'wearing', 'clown', 'makeup', 'and', 'holding', 'a', 'guitar', '.', '<eos>']]
# candidate
# ['three', 'men', 'are', 'standing', 'on', 'a', 'bench', ',', 'one', 'of', 'a', ',', 'and', 'a', 'a', 'and', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'girl', 'wearing', 'black', 'athletic', 'clothing', 'with', 'the', 'number', '<unk>', 'on', 'her', 'jersey', 'runs', 'across', 'some', 'grass', '.', '<eos>']]
# candidate
# ['a', 'girl', 'in', 'a', 'red', 'is', 'is', 'jumping', 'down', 'the', 'sidewalk', 'with', 'a', 'a', 'on', 'a', 'a', '.', '<eos>']
# reference
# [['a', 'small', 'boy', 'plays', 'with', 'plastic', 'blocks', ',', 'cars', ',', 'and', 'animals', 'with', 'an', 'adult', 'watching', 'closely', '.', '<eos>']]
# candidate
# ['a', 'little', 'boy', 'is', 'playing', 'with', 'a', '<unk>', 'while', 'while', 'while', 'others', 'watch', 'while', 'others', 'watch', '.', '<eos>']
# reference
# [['people', 'are', 'standing', 'on', 'a', 'crowded', 'subway', ',', 'and', 'the', 'platform', 'outside', 'is', 'visible', 'through', 'the', 'window', '.', '<eos>']]
# candidate
# ['people', 'standing', 'in', 'a', 'city', 'with', 'a', 'people', 'in', 'the', 'background', '.', '<eos>']
# reference
# [['the', 'two', 'dogs', ',', 'one', 'with', 'a', 'tennis', 'ball', 'in', 'its', 'mouth', ',', 'are', 'running', 'through', 'tall', 'grass', '.', '<eos>']]
# candidate
# ['the', 'two', 'black', 'dog', 'are', 'running', 'in', 'the', 'snow', 'with', 'a', 'stick', 'in', 'the', 'grass', '.', '<eos>']
# reference
# [['a', 'man', 'sitting', 'at', 'a', 'picnic', 'table', 'with', 'a', 'tray', 'and', 'partially', '<unk>', 'beer', 'in', 'front', 'of', 'him', '.', '<eos>']]
# candidate
# ['a', 'man', 'sits', 'on', 'a', 'chair', 'with', 'a', 'a', 'and', 'a', 'a', 'a', 'of', 'a', '.', '<eos>']
# reference
# [['a', 'female', 'police', 'officer', 'in', 'a', 'cap', 'and', 'navy', 'uniform', 'smiles', 'while', 'wearing', 'sunglasses', 'outside', 'of', 'a', 'shop', '.', '<eos>']]
# candidate
# ['a', 'lady', 'dressed', 'in', 'a', 'black', 'and', 'and', 'a', 'black', 'and', 'white', 'shirt', 'is', 'standing', 'front', 'of', 'a', 'large', 'wall', '.', '<eos>']
# count pair  1000
# bleu score
# 0.07048819578350113
# | Test Loss: 3.891 | Test PPL:  48.963 |
